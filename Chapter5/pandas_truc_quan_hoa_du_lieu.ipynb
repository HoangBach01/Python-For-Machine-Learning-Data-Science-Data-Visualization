# %%
# %config IPCompleter.greedy = True

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('du_lieu_4.xlsx')
print(df.shape, type(df))
# Out:
# (11, 3) <class 'pandas.core.frame.DataFrame'>

# %%
#df['Height'] = df['Height'] * 0.0254
#df['Weight'] = df['Weight'] *  0.453592
print(df)
# Out:
#     Height  Weight    Age
# 0       74     180  22.99
# 1       74     215  34.69
# 2       72     210  30.78
# 3       72     210  35.43
# 4       73     188  35.71
# 5       69     176  29.39
# 6       69     209  30.77
# 7       71     200  35.07
# 8       76     231  30.19
# 9       71     180  27.05
# 10      73     188  23.88

# %%
df.plot.bar()

# %%
df['Weight'].plot.bar()

# %%
df.plot.box()

# %%
df["Age"].plot.box()

# %%
df.plot.hist()

# %%
print(df['Weight'].values)
df['Weight'].plot.hist()
# Out:
# [180 215 210 210 188 176 209 200 231 180 188]

# %%
df.plot()

# %%
df['Height'].plot()

# %%
df['Height'].plot.pie()

# %%
ts = pd.Series(np.random.randn(100), index=pd.date_range('1/1/2015', periods=100))
ts.plot()

# %%
np.random.randn(100)
# Out:
# array([ 0.50327575,  0.2899597 , -0.45129731,  0.92815164,  1.05262506,
#        -0.8899543 , -0.08943787,  0.00674448, -0.31266688, -1.27302919,
#         0.56377493,  1.01632409, -0.61503403, -0.12502508, -0.67507202,
#         1.75654466, -0.77700064, -1.10428538,  0.14026966, -0.04411712,
#         0.47341284,  0.15779056, -0.52213195,  0.01560213,  1.50093268,
#         0.79970705, -0.36357619, -0.64207192,  0.22971729, -2.04954808,
#         0.56863643, -0.57499229, -1.33638944, -0.7686252 ,  0.85867183,
#         0.24871901,  2.25857952, -0.76630696,  0.33905167, -0.1663232 ,
#         0.2897391 ,  2.13751026,  0.26729097,  0.15666879,  0.10468581,
#        -0.61177665,  0.07970475,  2.02579878, -0.30431971,  0.13541653,
#         0.43164322,  1.2096028 ,  2.00859814,  1.27941115,  0.6163853 ,
#        -1.39616721,  0.96441782,  0.42145566, -0.31066185,  0.08018631,
#        -0.28034198,  0.03730091,  0.32781932, -0.74772954, -0.84346392,
# ...

# %%
print(pd.date_range('1/1/2015', periods=100))
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10', '2015-01-11', '2015-01-12',
#                '2015-01-13', '2015-01-14', '2015-01-15', '2015-01-16',
#                '2015-01-17', '2015-01-18', '2015-01-19', '2015-01-20',
#                '2015-01-21', '2015-01-22', '2015-01-23', '2015-01-24',
#                '2015-01-25', '2015-01-26', '2015-01-27', '2015-01-28',
#                '2015-01-29', '2015-01-30', '2015-01-31', '2015-02-01',
#                '2015-02-02', '2015-02-03', '2015-02-04', '2015-02-05',
#                '2015-02-06', '2015-02-07', '2015-02-08', '2015-02-09',
#                '2015-02-10', '2015-02-11', '2015-02-12', '2015-02-13',
#                '2015-02-14', '2015-02-15', '2015-02-16', '2015-02-17',
#                '2015-02-18', '2015-02-19', '2015-02-20', '2015-02-21',
# ...
