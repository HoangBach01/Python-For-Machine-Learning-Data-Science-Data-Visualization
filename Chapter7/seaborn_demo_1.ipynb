# %% [markdown]
# #### Comparing a histogram and distplot
# - The pandas library supports simple plotting of data, which is very convenient when data is already likely to be in a pandas DataFrame.
#
# - Seaborn generally does more statistical analysis on data and can provide more sophisticated insight into the data. In this exercise, we will compare a pandas histogram vs the seaborn distplot.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Read in the DataFrame
df = pd.read_csv("dataset/schoolimprovement2010grants.csv", index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 757 entries, 0 to 830
# Data columns (total 7 columns):
# School Name       757 non-null object
# City              757 non-null object
# State             757 non-null object
# District Name     757 non-null object
# Model Selected    757 non-null object
# Award_Amount      757 non-null int64
# Region            747 non-null object
# dtypes: int64(1), object(6)
# memory usage: 29.6+ KB

# %%
df.head()
# Out:
#                          School Name      City State  \
# 0  HOGARTH KINGEEKUK MEMORIAL SCHOOL  SAVOONGA    AK
# 1                    AKIACHAK SCHOOL  AKIACHAK    AK
# 2                     GAMBELL SCHOOL   GAMBELL    AK
# 3               BURCHELL HIGH SCHOOL   WASILLA    AK
# 4                       AKIAK SCHOOL     AKIAK    AK
#
#                                District Name  Model Selected  Award_Amount  \
# 0              BERING STRAIT SCHOOL DISTRICT  Transformation        471014
# 1                     YUPIIT SCHOOL DISTRICT  Transformation        520579
# 2              BERING STRAIT SCHOOL DISTRICT  Transformation        449592
# 3  MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT  Transformation        641184
# 4                     YUPIIT SCHOOL DISTRICT  Transformation        399686
#
#   Region
# 0   West
# 1   West
# 2   West
# 3   West
# 4   West

# %%
df
# Out:
#                                           School Name               City  \
# 0                   HOGARTH KINGEEKUK MEMORIAL SCHOOL           SAVOONGA
# 1                                     AKIACHAK SCHOOL           AKIACHAK
# 2                                      GAMBELL SCHOOL            GAMBELL
# 3                                BURCHELL HIGH SCHOOL            WASILLA
# 4                                        AKIAK SCHOOL              AKIAK
# 5                                      MIDVALLEY HIGH            WASILLA
# 6                                     TULUKSAK SCHOOL           TULUKSAK
# 7                         CAPITOL HEIGHTS JR HIGH SCH         MONTGOMERY
# 8                               LOWNDES CO MIDDLE SCH       FORT DEPOSIT
# 9                                  CENTRAL MIDDLE SCH           ROCKFORD
# 10                            BELLINGRATH JR HIGH SCH         MONTGOMERY
# 11                              HAYNEVILLE MIDDLE SCH         HAYNEVILLE
# 12                               SOUTHLAWN MIDDLE SCH         MONTGOMERY
# 13                            CONTINUOUS LEARNING CTR             MOBILE
# 14                            JACKSON-STEELE ELEM SCH         HAYNEVILLE
# 15                                MCINTYRE MIDDLE SCH         MONTGOMERY
# 16                                JOHN ESSEX HIGH SCH          DEMOPOLIS
# 17                                   CALHOUN HIGH SCH        LETOHATCHEE
# 18                              OSCEOLA MIDDLE SCHOOL            OSCEOLA
# 19                                   HALL HIGH SCHOOL        LITTLE ROCK
# 20                            ROSE CITY MIDDLE SCHOOL  NORTH LITTLE ROCK
# 21                           TRUSTY ELEMENTARY SCHOOL         FORT SMITH
# 22                              J.A. FAIR HIGH SCHOOL        LITTLE ROCK
# 23                                OSCEOLA HIGH SCHOOL            OSCEOLA
# 24                           CLOVERDALE MIDDLE SCHOOL        LITTLE ROCK
# 25                          GADSDEN ELEMENTARY SCHOOL            GADSDEN
# 26                            EAST VALLEY HIGH SCHOOL               MESA
# 27                           CRITTENTON YOUTH ACADEMY            PHOENIX
# 28                               ALCHESAY HIGH SCHOOL         WHITERIVER
# 29                             SAN CARLOS HIGH SCHOOL         SAN CARLOS
# ..                                                ...                ...
# 801                          WASHINGTON MIDDLE SCHOOL             YAKIMA
# 802  FOSTER & WILLIAMS HIGH SCHOOL OF THE VISUAL ARTS          MILWAUKEE
# 803                                       DUBOIS HIGH          MILWAUKEE
# 804                                       CUSTER HIGH          MILWAUKEE
# 805                     JAMES MADISON ACADEMIC CAMPUS          MILWAUKEE
# 806                                      VINCENT HIGH          MILWAUKEE
# 807                                     BAY VIEW HIGH          MILWAUKEE
# 808       DOWNTOWN INSTITUTE OF ARTS & LETTERS (DIAL)          MILWAUKEE
# 809                               SOUTH DIVISION HIGH          MILWAUKEE
# 810         MILWAUKEE AFRICAN AMERICAN IMMERSION HIGH          MILWAUKEE
# 811                WHS LAW EDUCATION & PUBLIC SERVICE          MILWAUKEE
# 812                           BRADLEY TECHNOLOGY HIGH          MILWAUKEE
# 813                                       HAMLIN PK-8             HAMLIN
# 814                             RIVERSIDE HIGH SCHOOL              BELLE
# 815                DODDRIDGE COUNTY ELEMENTARY SCHOOL         WEST UNION
# 816                            MOUNT VIEW HIGH SCHOOL              WELCH
# 817                            WEST HAMLIN ELEMENTARY        WEST HAMLIN
# 818                          MALDEN ELEMENTARY SCHOOL         CHARLESTON
# 819                   MARTINSBURG NORTH MIDDLE SCHOOL        MARTINSBURG
# 820                         SANDY RIVER MIDDLE SCHOOL           AVONDALE
# 821                   STONEWALL JACKSON MIDDLE SCHOOL         CHARLESTON
# 822                           EAST BANK MIDDLE SCHOOL          EAST BANK
# 823                        FRANKLIN ELEMENTARY CENTER        PARKERSBURG
# 824                               GUYAN VALLEY MIDDLE         BRANCHLAND
# 825                         CEDAR GROVE MIDDLE SCHOOL        CEDAR GROVE
# 826                            MOUNT HOPE HIGH SCHOOL         MOUNT HOPE
# 827                           GEARY ELEMENTARY SCHOOL          LEFT HAND
# 828                               TRIUMPH HIGH SCHOOL           CHEYENNE
# 829                     HEM JUNIOR/SENIOR HIGH SCHOOL              HANNA
# 830                             ROOSEVELT HIGH SCHOOL             CASPER
#
#     State                                  District Name  Model Selected  \
# 0      AK                  BERING STRAIT SCHOOL DISTRICT  Transformation
# 1      AK                         YUPIIT SCHOOL DISTRICT  Transformation
# 2      AK                  BERING STRAIT SCHOOL DISTRICT  Transformation
# 3      AK      MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT  Transformation
# 4      AK                         YUPIIT SCHOOL DISTRICT  Transformation
# 5      AK      MATANUSKA-SUSITNA BOROUGH SCHOOL DISTRICT         Restart
# 6      AK                         YUPIIT SCHOOL DISTRICT  Transformation
# 7      AL                              MONTGOMERY COUNTY  Transformation
# 8      AL                                 LOWNDES COUNTY  Transformation
# 9      AL                                   COOSA COUNTY  Transformation
# 10     AL                              MONTGOMERY COUNTY  Transformation
# 11     AL                                 LOWNDES COUNTY  Transformation
# 12     AL                              MONTGOMERY COUNTY  Transformation
# 13     AL                                  MOBILE COUNTY  Transformation
# 14     AL                                 LOWNDES COUNTY  Transformation
# 15     AL                              MONTGOMERY COUNTY  Transformation
# 16     AL                                 MARENGO COUNTY  Transformation
# 17     AL                                 LOWNDES COUNTY  Transformation
# 18     AR                        OSCEOLA SCHOOL DISTRICT  Transformation
# 19     AR                    LITTLE ROCK SCHOOL DISTRICT  Transformation
# 20     AR                 N. LITTLE ROCK SCHOOL DISTRICT  Transformation
# 21     AR                     FORT SMITH SCHOOL DISTRICT  Transformation
# 22     AR                    LITTLE ROCK SCHOOL DISTRICT  Transformation
# 23     AR                        OSCEOLA SCHOOL DISTRICT  Transformation
# 24     AR                    LITTLE ROCK SCHOOL DISTRICT  Transformation
# 25     AZ                    GADSDEN ELEMENTARY DISTRICT  Transformation
# 26     AZ                         LEGACY EDUCATION GROUP      Turnaround
# 27     AZ  FLORENCE CRITTENTON SERVICES OF ARIZONA  INC.      Turnaround
# 28     AZ                    WHITERIVER UNIFIED DISTRICT  Transformation
# 29     AZ                    SAN CARLOS UNIFIED DISTRICT  Transformation
# ..    ...                                            ...             ...
# 801    WA                         YAKIMA SCHOOL DISTRICT  Transformation
# 802    WI                      MILWAUKEE SCHOOL DISTRICT         Closure
# 803    WI                      MILWAUKEE SCHOOL DISTRICT         Closure
# 804    WI                      MILWAUKEE SCHOOL DISTRICT         Restart
# 805    WI                      MILWAUKEE SCHOOL DISTRICT  Transformation
# 806    WI                      MILWAUKEE SCHOOL DISTRICT  Transformation
# 807    WI                      MILWAUKEE SCHOOL DISTRICT  Transformation
# 808    WI                      MILWAUKEE SCHOOL DISTRICT         Closure
# 809    WI                      MILWAUKEE SCHOOL DISTRICT  Transformation
# 810    WI                      MILWAUKEE SCHOOL DISTRICT         Restart
# 811    WI                      MILWAUKEE SCHOOL DISTRICT         Closure
# 812    WI                      MILWAUKEE SCHOOL DISTRICT  Transformation
# 813    WV                         LINCOLN COUNTY SCHOOLS  Transformation
# 814    WV                         KANAWHA COUNTY SCHOOLS  Transformation
# 815    WV                       DODDRIDGE COUNTY SCHOOLS  Transformation
# 816    WV                        MCDOWELL COUNTY SCHOOLS  Transformation
# 817    WV                         LINCOLN COUNTY SCHOOLS  Transformation
# 818    WV                         KANAWHA COUNTY SCHOOLS  Transformation
# 819    WV                        BERKELEY COUNTY SCHOOLS  Transformation
# 820    WV                        MCDOWELL COUNTY SCHOOLS  Transformation
# 821    WV                         KANAWHA COUNTY SCHOOLS  Transformation
# 822    WV                         KANAWHA COUNTY SCHOOLS  Transformation
# 823    WV                            WOOD COUNTY SCHOOLS  Transformation
# 824    WV                         LINCOLN COUNTY SCHOOLS  Transformation
# 825    WV                         KANAWHA COUNTY SCHOOLS  Transformation
# 826    WV                         FAYETTE COUNTY SCHOOLS  Transformation
# 827    WV                           ROANE COUNTY SCHOOLS  Transformation
# 828    WY              LARAMIE COUNTY SCHOOL DISTRICT #1  Transformation
# 829    WY               CARBON COUNTY SCHOOL DISTRICT #2  Transformation
# 830    WY              NATRONA COUNTY SCHOOL DISTRICT #1  Transformation
#
#      Award_Amount   Region
# 0          471014     West
# 1          520579     West
# 2          449592     West
# 3          641184     West
# 4          399686     West
# 5          697703     West
# 6          427658     West
# 7          110544    South
# 8           12973    South
# 9          199828    South
# 10         165903    South
# 11         121657    South
# 12         914557    South
# 13         198953    South
# 14         118394    South
# 15         143238    South
# 16         151116    South
# 17         163619    South
# 18         665000    South
# 19         198728    South
# 20         991451    South
# 21         990135    South
# 22         197012    South
# 23         695000    South
# 24         198783    South
# 25         847003     West
# 26         381512     West
# 27         915959     West
# 28         812195     West
# 29         928654     West
# ..            ...      ...
# 801        115268     West
# 802         10000  Midwest
# 803         10000  Midwest
# 804        650093  Midwest
# 805        749320  Midwest
# 806        928024  Midwest
# 807        134909  Midwest
# 808         10000  Midwest
# 809        124643  Midwest
# 810        567905  Midwest
# 811         10000  Midwest
# 812         10000  Midwest
# 813        258600    South
# 814        481900    South
# 815        464200    South
# 816        450000    South
# 817        156660    South
# 818        217598    South
# 819        461690    South
# 820        370000    South
# 821        241211    South
# 822        314618    South
# 823        389906    South
# 824        341250    South
# 825        211271    South
# 826        342189    South
# 827        260000    South
# 828        297300     West
# 829        274000     West
# 830        431382     West
#
# [757 rows x 7 columns]

# %%
# Display a Seaborn distplot
plt.figure(figsize=(10,6))
sns.distplot(df['Award_Amount'])
plt.show()

# %%
# Create a distplot
plt.figure(figsize=(10,6))
sns.distplot(df['Award_Amount'], kde=False, bins=20, color='purple')
# Display a plot
plt.show()

# %% [markdown]
# #### Rug plot and kde shading
# - Now that you understand some function arguments for distplot(), we can continue further refining the output. This process of creating a visualization and updating it in an incremental fashion is a useful and common approach to look at data from multiple perspectives.
#
# - Seaborn excels at making this process simple.

# %%
# Create a distplot of the Award Amount
plt.figure(figsize=(10,6))
sns.distplot(df['Award_Amount'], hist=False, rug=True)
# Plot the results
plt.show()

# %%
# Create a distplot of the Award Amount
plt.figure(figsize=(10,6))
sns.distplot(df['Award_Amount'], hist=False, rug=True, kde_kws={'shade':'kde_kws'})
# Plot the results
plt.show()

# %%
# Create a distplot of the Award Amount
plt.figure(figsize=(10,6))
sns.distplot(df['Award_Amount'],
             hist=False,
             rug=True,
             kde_kws={'shade':True})

# Plot the results
plt.show()
