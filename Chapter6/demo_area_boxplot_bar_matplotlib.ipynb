# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Tham khảo: https://www.data-to-viz.com/graph/area.html
# https://matplotlib.org/gallery/pyplots/boxplot_demo_pyplot.html#sphx-glr-gallery-pyplots-boxplot-demo-pyplot-py

# %%
# Create data
x=range(1,15)
y=[1,4,6,8,4,5,3,2,4,1,5,6,8,7]

# %%
# Area plot
plt.fill_between(x, y)
plt.show()

# %%
# Create data
x=range(1,15)
y=[1,4,6,8,4,5,3,2,4,1,5,6,8,7]
 
# Change color, and its transparency
plt.fill_between( x, y, color="skyblue", alpha=0.5)
# Add a stronger line on top 
plt.plot(x, y, color="Slateblue", alpha=0.6)
plt.grid(True)
plt.show()

# %%
import numpy as np

# %%
# create data
price = np.array([15, 45, 50, 120, 300, 34, 55, 70, 105, 85])
# box plot
plt.boxplot(price)
plt.show()

# %%
print(np.quantile(price,0.25))
print(np.quantile(price,0.50))
print(np.quantile(price,0.75))
print(np.quantile(price,1.0))
# Out:
# 46.25
# 62.5
# 100.0
# 300.0

# %%
# Have notch at median, change outlier symbol
green_diamond = dict(markerfacecolor='g', marker='D')
plt.boxplot(price, notch=True, flierprops = green_diamond)
plt.show()

# %%
# Horizontal Boxes
red_square = dict(markerfacecolor='r', marker='s')
plt.boxplot(price, vert=False, flierprops=red_square)
plt.show()

# %%
# create data
people = ['Tom', 'Dick', 'Harry', 'Slim', 'Jim']
marks = [6, 8, 9, 7, 10]
y_pos = np.arange(len(people))

# Horizontal bar chart
plt.barh(y_pos, marks, align='center',
        color='green', ecolor='black')
plt.yticks(y_pos, people)
plt.xlabel('Marks')
plt.title('Who has the highest mark?', color = 'red')
plt.show()
