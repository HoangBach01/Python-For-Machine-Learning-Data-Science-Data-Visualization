# %%
# Vào ngày 15 tháng 4 năm 1912, trong chuyến hành trình đầu tiên của mình, tàu Titanic đã gặp tai nạn sau khi va chạm với một tảng băng trôi, đã có 1502 người mãi mãi ra đi trong tổng số 2224 hành khách và phi hành đoàn.

# Thông tin về Titanic Disaster có thể xem tại: https://www.kaggle.com/c/titanic/data

# Dựa trên tập tin train.csv,  hãy hoàn tất file đính kèm để phân tích về Titanic Disaster:
# 1.	a) Đọc dữ liệu từ tập tin train.csv và lưu vào biến titanic. Hiển thị 5 dòng dữ liệu đầu của titanic.
#         b) Thiết lập cột index cho titanic là PassengerId. Hiển thị lại 5 dòng dữ liệu đầu của titanic lúc này.
# 2.	Tạo pie chart thể hiện tỷ lệ hành khách nam/nữ trên tàu
# 3.	Cho biết có bao nhiêu người còn sống sót
# 4.	Vẽ biểu đồ histogram của cột vé (Fare)
#         Bạn nhận xét gì về biểu đồ vừa vẽ.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
titanic = pd.read_csv('../data/train.csv',index_col='PassengerId')
titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
# 2.	Tạo pie chart thể hiện tỷ lệ hành khách nam/nữ trên tàu
titanic_by_sex = titanic.groupby('Sex').count()
titanic_by_sex
# Out:
#         Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  Cabin  \
# Sex
# female       314     314   314  261    314    314     314   314     97
# male         577     577   577  453    577    577     577   577    107
#
#         Embarked
# Sex
# female       312
# male         577

# %%
plt.style.use('default')
plt.pie(titanic_by_sex['Name'], labels=titanic_by_sex.index, 
        explode= [0.15,0], startangle=90, autopct='%1.1f%%', 
        shadow=True, wedgeprops={'edgecolor': 'black'}, counterclock=False)

plt.title('Percentage Male/Female on Titanic')

plt.show()

# %%
num_survived = titanic['Survived'].sum()
num_survived
# Out:
# 342

# %%
plt.hist(titanic['Fare'], bins=50)

plt.title("Histogram Ticket Price")
plt.xlabel('Price per ticket')
plt.ylabel('No. Ticket')
plt.show()
